# %%
import pandas as pd

# %%
movies_df = pd.read_csv('movies.csv', sep = ';')

# %%
movies_df.head()
# Out:
#    id                                        description  \
# 0   1  Tanjirō Kamado, joined with Inosuke Hashibira,...
# 1   2  A portal transports Cpt. Artemis and an elite ...
# 2   3  A botched store robbery places Wonder Woman in...
# 3   4  After the vicious slaughter of his family by s...
# 4   5  A group of unlikely heroes from across the Kor...
#
#                                           image_path  \
# 0  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 1  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 2  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 4  https://www.themoviedb.org/t/p/w600_and_h900_b...
#
#                  release_date  \
# 0  2020-10-16 00:00:00.000000
# 1  2020-12-03 00:00:00.000000
# 2  2020-12-16 00:00:00.000000
# 3  2020-04-12 00:00:00.000000
# 4  2019-12-19 00:00:00.000000
#
#                                                title  tmdb_id
# ...

# %%
movies_df = movies_df.set_index('id')
movies_df.head()
# Out:
#                                           description  \
# id
# 1   Tanjirō Kamado, joined with Inosuke Hashibira,...
# 2   A portal transports Cpt. Artemis and an elite ...
# 3   A botched store robbery places Wonder Woman in...
# 4   After the vicious slaughter of his family by s...
# 5   A group of unlikely heroes from across the Kor...
#
#                                            image_path  \
# id
# 1   https://www.themoviedb.org/t/p/w600_and_h900_b...
# 2   https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3   https://www.themoviedb.org/t/p/w600_and_h900_b...
# 4   https://www.themoviedb.org/t/p/w600_and_h900_b...
# 5   https://www.themoviedb.org/t/p/w600_and_h900_b...
#
#                   release_date  \
# id
# 1   2020-10-16 00:00:00.000000
# 2   2020-12-03 00:00:00.000000
# 3   2020-12-16 00:00:00.000000
# 4   2020-04-12 00:00:00.000000
# 5   2019-12-19 00:00:00.000000
#
#                                                 title  tmdb_id
# id
# ...

# %%
movies_df.shape
# Out:
# (1050, 5)
